# %% [markdown]
# ## Chapter 2 Question 1

# %% [markdown]
# ## Sawtooth signal

# %% [markdown]
# Some facts : 1.Sawtooth signal is a kind of non-sinusoidal waveform
#              2.It resemblance to the teeth of a plain-toothed saw with a zero rake angle.

# %% [markdown]
# ## Libraries

# %%
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot
import numpy as np
import math

import warnings
warnings.filterwarnings('ignore')

from IPython.html.widgets import interact, interact_manual, fixed
from IPython.html import widgets
from IPython.display import display

PI2 = 2 * math.pi

# %% [markdown]
# ## Constructing a Sawtooth Signal

# %%
signal = thinkdsp.SawtoothSignal(500)
wave = signal.make_wave(duration=10, framerate=10000)
segment = wave.segment(duration=0.005)
segment.plot()

# %% [markdown]
# ## Convert the generated sawtooth signal to audio

# %% [markdown]
# Purpose: To play the generated sawtooth signal

# %%
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Question 2 Part 1 : Write a class called SawtoothSignal that extends Signal and provides evaluate to evaluate a sawtooth signal.

# %%
class SawtoothSignal(thinkdsp.Sinusoid):
    """Represents a sawtooth signal."""
    
    def evaluate(self, ts):
        """Evaluates the signal at the given times.

        ts: float array of times
        
        returns: float wave array
        """
        cycles = self.freq * ts + self.offset / PI2
        frac, _ = np.modf(cycles)
        ys = thinkdsp.normalize(thinkdsp.unbias(frac), self.amp)
        return ys

# %% [markdown]
# ## For generating new Sawtooth Signal

# %%
sawtooth = SawtoothSignal().make_wave(duration=10, framerate=40000)

# %% [markdown]
# ## Ploting the generated Square Signal¶

# %%
sawtooth.plot()

# %%
segment = sawtooth.segment(duration=0.005)
segment.plot()

# %% [markdown]
# ## Converting the generated Sawtooth signal to audio

# %%
sawtooth.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Evaluating your own created Sawtooth Signal

# %%
def evaluate(wave,ts):
    cycle=wave.freq * ts + wave.offset / PI2
    frac,_=np.modf(cycles)
    ys=thinkdsp.normalize(thinkdsp.unbias(frac), wave.amp)
    return ys

# %% [markdown]
# ## Question 2 part 2 :Compute the spectrum of a sawtooth wave.

# %%
sawtooth.make_spectrum().plot()

# %% [markdown]
# Question 2 part 3: How does the harmonic structure compare to triangle and square waves?

# %% [markdown]
# ## Constructing a Square Signal

# %%
square = thinkdsp.SquareSignal(amp=0.5).make_wave(duration=10, framerate=40000)

# %% [markdown]
# ## Ploting the generated Square Signal¶

# %%
segment = square.segment(duration=0.005)
segment.plot()

# %% [markdown]
# ## Converting Square Signal to Audio

# %%
square.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Calculating spectrum of Square Signal and Plotting it

# %%
square.make_spectrum().plot()

# %% [markdown]
# ## Plotting Sawtooth Signal and Square Signal

# %%
#Sawtooth in blue color
# Sqare wave in red color


sawtooth.make_spectrum().plot(color='blue')
square.make_spectrum().plot(color='red')

# %% [markdown]
# Compared to a square wave, the sawtooth drops off similarly, but it includes both even and odd harmonics.
# To make square wave and Sawtooth wave comparable, one way can be by cutting the amplitude of the square wave

# %% [markdown]
# ## Constructing a Triangle Signal

# %%
triangle = thinkdsp.TriangleSignal(amp=0.5).make_wave(duration=10, framerate=40000)

# %% [markdown]
# ## Ploting the generated Triangle Signal¶

# %%
segment = triangle.segment(duration=0.005)
segment.plot()

# %% [markdown]
# ## Converting Triangle Signal to Audio

# %%
triangle.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Calculating spectrum of Triangle Signal and Plotting it

# %%
triangle.make_spectrum().plot()

# %% [markdown]
# ## Plotting Triangle Signal and Sawtooth Signal

# %%
#Sawtooth in blue color
#Triangle wave in yellow color


sawtooth.make_spectrum().plot(color='blue')
triangle.make_spectrum().plot(color='yellow')

# %% [markdown]
# ## Plotting Triangle Signal, Sawtooth and Square Signal

# %%
#Sawtooth in black color
#Triangle wave in blue color
#Sqare wave in yellow color


sawtooth.make_spectrum().plot(color='black')
triangle.make_spectrum().plot(color='blue')
square.make_spectrum().plot(color='yellow')
